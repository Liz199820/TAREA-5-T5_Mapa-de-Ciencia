# %% [markdown]
# <img src="https://www.ikiam.edu.ec/img/logo-ikiam-grey.png" width=400 height=300 />
# <center><h2> INGENIERÍA EN BIOTECNOLOGÍA</h2></center>
# <h1 style="color:purple">GBI6 - BIOINFORMÁTICA</h1></center>
# <h1 style="color:black">LIZETH GARCIA</h1></center>
#
#
# #  TAREA # 5 T5_Mapa-de-Ciencia

# %%
# Primero, se importó las librerías
import re
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Se realizó el minado de autores por país
with open('pubmed-gravitydri-set.txt',"r", encoding='utf-8-sig') as f:
    word = f.read()

word = re.sub(r'\n\s{6}', ' ', word)

wrd = re.findall (r"\,\s[A-Z]+[A-z]{2,11}\.", word)
unique_wrd = list(set(wrd))
unique_wrd.sort ()

unique_wrd.remove(", Inc.")
unique_wrd.remove(", California.")
unique_wrd.remove(", Fla.")
unique_wrd.remove(", Ltd.")
unique_wrd.remove(", Wash.")
unique_wrd.remove(", Basel.")
unique_wrd.remove(", Beijing.")
unique_wrd.remove(", Butenandtstr.")
unique_wrd.remove(", Univ.")
unique_wrd.remove(", Phys.")
unique_wrd.remove(", Weinheim.")

a = "".join(unique_dat)
b = a.split(", ")
c = "".join(b)
From = c.split(".")
From.remove("")
print("Paises: ", From)
# Con print se puede observar la lista de países y se hizo una eliminación de los elementos repetidos y que no eran países
# Out:
# Paises:  ['Argentina', 'Australia', 'Austria', 'Bangladesh', 'Belgium', 'Brazil', 'Brunei', 'Canada', 'Chile', 'China', 'Colombia', 'Commun', 'Denmark', 'Egypt', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Ireland', 'Israel', 'Italy', 'Japan', 'Korea', 'Luxembourg', 'Malaysia', 'Maryland', 'Michigan', 'Monaco', 'Nepal', 'Netherlands', 'Nigeria', 'Norway', 'Pakistan', 'Poland', 'Qatar', 'Russia', 'Singapore', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'USA', 'Uruguay', 'Vietnam']

# %%
len (From)
# Out:
# 53

# %%
# Se importó la tabla de "Ubicación Geográfica de Países - Google Developer"
data = pd.read_csv('./paises_ubicacion.csv', engine='python', skipfooter=3)
data.head(7)
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla
# 5      AL  41.153332  20.168331               Albania
# 6      AM  40.069099  45.038189               Armenia

# %%
# Para asignar las ubicaciones geográfica de los centroides de cada país (latitud y longitud)
data = data[data.name.isin(From)]
data.head(53)
# Out:
#     country   latitude   longitude         name
# 10       AR -38.416097  -63.616672    Argentina
# 12       AT  47.516231   14.550072      Austria
# 13       AU -25.274398  133.775136    Australia
# 18       BD  23.684994   90.356331   Bangladesh
# 19       BE  50.503887    4.469936      Belgium
# 26       BN   4.535277  114.727669       Brunei
# 28       BR -14.235004  -51.925280       Brazil
# 35       CA  56.130366 -106.346771       Canada
# 40       CH  46.818188    8.227512  Switzerland
# 43       CL -35.675147  -71.542969        Chile
# 45       CN  35.861660  104.195397        China
# 46       CO   4.570868  -74.297333     Colombia
# 53       DE  51.165691   10.451526      Germany
# 55       DK  56.263920    9.501785      Denmark
# 60       EE  58.595272   25.013607      Estonia
# 61       EG  26.820553   30.802498        Egypt
# 64       ES  40.463667   -3.749220        Spain
# 66       FI  61.924110   25.748151      Finland
# 71       FR  46.227638    2.213749       France
# ...

# %%
mapa=pd.concat([data]).drop_duplicates().sort_values('name')

# %%
# Se resaltó a los siguientes países: USA, UK, Brazil, China, Australia, Norway y se realizó la gráfica.
plt.scatter(mapa.longitude, mapa.latitude, s=50, c=mapa.latitude)
plt.colorbar()
ard = dict(arrowstyle="->")

plt.annotate('USA', xy = (-95.712891, 37.09024), 
               xytext = (-95.712891, 40), arrowprops = ard)
plt.annotate('UKRAINE', xy = (31.16558,48.379433), 
               xytext = (31.16558,51), arrowprops= ard)
plt.annotate('BRAZIL', xy = (-51.92528, -14.235004), 
               xytext = (-51.92528, -11), arrowprops= ard)
plt.annotate('CHINA', xy = (104.195397, 35.86166), 
               xytext = (104.195397, 39), arrowprops= ard)
plt.annotate('AUSTRALIA', xy = (133.775136, -25.274398), 
               xytext = (133.775136, -22), arrowprops= ard)
plt.annotate('NORWAY', xy = (8.468946, 60.472024), 
               xytext = (8.468946, 63), arrowprops= ard)

params = plt.gcf()
plSize = params.get_size_inches()
params.set_size_inches( (plSize[0] * 3, plSize[1] * 3) )

# %%
:)
